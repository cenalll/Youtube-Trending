# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
youtube_us=pd.read_csv('USvideos.csv')

# %%
youtube_us.head(5)
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
youtube_us.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 16 columns):
# video_id                  40949 non-null object
# trending_date             40949 non-null object
# title                     40949 non-null object
# channel_title             40949 non-null object
# category_id               40949 non-null int64
# publish_time              40949 non-null object
# tags                      40949 non-null object
# views                     40949 non-null int64
# likes                     40949 non-null int64
# dislikes                  40949 non-null int64
# comment_count             40949 non-null int64
# thumbnail_link            40949 non-null object
# comments_disabled         40949 non-null bool
# ratings_disabled          40949 non-null bool
# video_error_or_removed    40949 non-null bool
# description               40379 non-null object
# dtypes: bool(3), int64(5), object(8)
# memory usage: 4.2+ MB

# %%
import json

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns
# %matplotlib inline

# %%
cate_id_to_category={}

with open('US_category_id.json', 'r') as f:
    data=json.load(f)
    for category in data['items']:
        cate_id_to_category[category['id']] = category['snippet']['title']

# %%
cate_id_to_category
# Out:
# {'1': 'Film & Animation',
#  '2': 'Autos & Vehicles',
#  '10': 'Music',
#  '15': 'Pets & Animals',
#  '17': 'Sports',
#  '18': 'Short Movies',
#  '19': 'Travel & Events',
#  '20': 'Gaming',
#  '21': 'Videoblogging',
#  '22': 'People & Blogs',
#  '23': 'Comedy',
#  '24': 'Entertainment',
#  '25': 'News & Politics',
#  '26': 'Howto & Style',
#  '27': 'Education',
#  '28': 'Science & Technology',
#  '29': 'Nonprofits & Activism',
#  '30': 'Movies',
#  '31': 'Anime/Animation',
#  '32': 'Action/Adventure',
#  '33': 'Classics',
#  '34': 'Comedy',
#  '35': 'Documentary',
#  '36': 'Drama',
#  '37': 'Family',
#  '38': 'Foreign',
#  '39': 'Horror',
#  '40': 'Sci-Fi/Fantasy',
#  '41': 'Thriller',
#  '42': 'Shorts',
#  '43': 'Shows',
#  '44': 'Trailers'}

# %%
youtube_us.insert(4,'category', youtube_us['category_id'].astype(str).map(cate_id_to_category))
youtube_us[['category_id', 'category']].head(10)
# Out:
#    category_id              category
# 0           22        People & Blogs
# 1           24         Entertainment
# 2           23                Comedy
# 3           24         Entertainment
# 4           24         Entertainment
# 5           28  Science & Technology
# 6           24         Entertainment
# 7           28  Science & Technology
# 8            1      Film & Animation
# 9           25       News & Politics

# %%
youtube_us.sort_values('views',ascending=False,inplace=True)
x_axis=youtube_us.head(10)
x_axis
# Out:
#           video_id trending_date  \
# 38547  VYOjWnS4cMY      18.02.06
# 38345  VYOjWnS4cMY      18.01.06
# 38146  VYOjWnS4cMY      18.31.05
# 37935  VYOjWnS4cMY      18.30.05
# 37730  VYOjWnS4cMY      18.29.05
# 37531  VYOjWnS4cMY      18.28.05
# 37333  VYOjWnS4cMY      18.27.05
# 37123  VYOjWnS4cMY      18.26.05
# 36913  VYOjWnS4cMY      18.25.05
# 36710  VYOjWnS4cMY      18.24.05
#
#                                                    title        channel_title  \
# 38547  Childish Gambino - This Is America (Official V...  ChildishGambinoVEVO
# 38345  Childish Gambino - This Is America (Official V...  ChildishGambinoVEVO
# 38146  Childish Gambino - This Is America (Official V...  ChildishGambinoVEVO
# 37935  Childish Gambino - This Is America (Official V...  ChildishGambinoVEVO
# 37730  Childish Gambino - This Is America (Official V...  ChildishGambinoVEVO
# 37531  Childish Gambino - This Is America (Official V...  ChildishGambinoVEVO
# ...

# %%
#The most viewed video in 10 days is the offical video of "This is America"
#https://www.youtube.com/watch?v=VYOjWnS4cMY

#really??????

# %%
youtube_us = youtube_us[~youtube_us['title'].duplicated(keep='last')] 
youtube_us['title'].duplicated().any()
# Out:
# False

# %%
def max_visualized(youtube_us,column,num=10):
    max_youtube_us=youtube_us.sort_values(column,ascending=False).iloc[:num]
    
    fig,ax=plt.subplots()
    ax.barh(max_youtube_us['title'],max_youtube_us[column])
    
    ax.set(xlabel=column,title ='Top %s %s of video' %(num,column))

# %%
max_visualized(youtube_us,'views',20)

# %%
max_visualized(youtube_us,'likes',20)

# %%
max_visualized(youtube_us,'dislikes',20)

# %%
max_visualized(youtube_us,'comment_count',20)

# %%
sns.factorplot('category',data=youtube_us,size = 7.5, aspect = 3,hue='category',kind='count',legend_out=True)

# %%
youtube_us['views_log'] = np.log(youtube_us['views'] + 1)

plt.figure(figsize = (20,8))
plt.title('Views distribution by category')
plt.xticks(rotation=20)
sns.boxplot(x='category',y='views_log',data=youtube_us, width=0.5,palette='Set1')

# %%
youtube_us['likes_log'] = np.log(youtube_us['likes'] + 1)

plt.figure(figsize = (20,8))
plt.title('Likes distribution by category')
plt.xticks(rotation=20)
sns.boxplot(x='category',y='likes_log',data=youtube_us, width=0.5,palette='Set1')

# %%
youtube_us['dislikes_log'] = np.log(youtube_us['dislikes'] + 1)

plt.figure(figsize = (20,8))
plt.title('Dislikes distribution by category')
plt.xticks(rotation=20)
sns.boxplot(x='category',y='dislikes_log',data=youtube_us, width=0.5,palette='Set1')

# %%
youtube_us['comment_count_log'] = np.log(youtube_us['comment_count'] + 1)

plt.figure(figsize = (20,8))
plt.title('Comments distribution by category')
plt.xticks(rotation=20)
sns.boxplot(x='category',y='comment_count_log',data=youtube_us, width=0.5,palette='Set1')

# %%
youtube_us['like_rate']=youtube_us['likes']/youtube_us['views']*100
youtube_us['dislike_rate']=youtube_us['dislikes']/youtube_us['views']*100
youtube_us['comment_rate']=youtube_us['comment_count']/youtube_us['views']*100

# %%
plt.figure(figsize = (10,8))
plt.title('Rate distribution')
sns.distplot(youtube_us['like_rate'],color='red',hist=False,label='Likes')
sns.distplot(youtube_us['dislike_rate'],color='green',hist=False,label='Dislikes')
sns.distplot(youtube_us['comment_rate'],color='blue',hist=False,label='Comments')

# %%
sns.pairplot(youtube_us,x_vars=['views','comment_count'],y_vars=['likes','dislikes'],markers='o',size=6)

# %%
sns.lmplot(x='likes',y='dislikes',data=youtube_us,size=8, scatter_kws={'marker':'o','color':'pink'},line_kws={'linewidth':1,'color':'black'})

# %%
sns.lmplot(x='likes',y='views',data=youtube_us,size=8, scatter_kws={'marker':'o','color':'pink'},line_kws={'linewidth':1,'color':'black'})

# %%
sns.lmplot(x='likes',y='comment_count',data=youtube_us,size=8, scatter_kws={'marker':'o','color':'pink'},line_kws={'linewidth':1,'color':'black'})

# %%
plt.figure(figsize=(10,8))

plt.subplot(221)
p1=sns.distplot(np.log(youtube_us['views']+1))
plt.title('Views Distribution',fontsize=12)

plt.subplot(222)
p2 = sns.distplot(np.log(youtube_us['comment_count']+1))
plt.title('Comments Distribution', fontsize=12)

plt.subplot(223)
p3 = sns.distplot(np.log(youtube_us['dislikes']+1))
plt.title('Dislikes Distribution', fontsize=12)

plt.subplot(224)
p4 = sns.distplot(np.log(youtube_us['likes']+1))
plt.title('Likes Distribution', fontsize=12)

plt.subplots_adjust(wspace = 0.2, hspace = 0.5,top = 0.8)
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.heatmap(youtube_us[['comment_count_log','likes_log','dislikes_log','comment_rate','like_rate','dislike_rate','views_log']].corr(),annot=True)

# %%
youtube_us['trending_date'] = pd.to_datetime(youtube_us['trending_date'], format='%y.%d.%m')

# %%
youtube_us['publish_time'] = pd.to_datetime(youtube_us['publish_time'], format='%Y-%m-%dT%H:%M:%S.%fZ',errors='coerce')

# %%
youtube_us.insert(4, 'publish_date', youtube_us['publish_time'].dt.date)
youtube_us['publish_time'] = youtube_us['publish_time'].dt.time
youtube_us[['publish_date', 'publish_time']].head()
# Out:
#       publish_date publish_time
# 23824   2018-03-09     11:00:01
# 35550   2018-05-18     09:00:02
# 28605   2018-04-09     08:59:51
# 3200    2017-11-29     13:26:24
# 70      2017-11-09     11:04:14

# %%
youtube_us['publish_day']=youtube_us['publish_date'].apply(lambda time : time.day)

# %%
publish_date_vs_category=youtube_us.groupby(['category','publish_day'])['views'].sum()
pub_vs_cate=publish_date_vs_category.unstack().fillna(0)

plt.figure(figsize=(12,12))
plt.title('Category VS Public date')
sns.heatmap(pub_vs_cate)
